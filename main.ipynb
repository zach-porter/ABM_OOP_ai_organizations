# %%
# main.py
from model import OrganizationModel

def main():
    # Initialize the model with desired parameters
    model = OrganizationModel(
        num_employees=100,         # Total number of employees
        num_levels=5,              # Increased to 5 to include all agents
        span_of_control=3,         # Decreased to 3
        org_network_type='hierarchical',  # 'hierarchical' or 'onion'
        social_network_type='small_world', # 'small_world' or 'scale_free'
        social_k=4,                # For small-world: number of neighbors
        social_p=0.1,              # For small-world: rewiring probability
        social_m=2,                # For scale-free: number of edges to attach
        ai_contribution=2.0,       # AI's initial knowledge contribution per interaction
        knowledge_decay_rate=0.05, # Knowledge decay rate per step
        ai_evolution_threshold=15, # AI evolves if used more than this threshold
        ai_evolution_decrement_threshold=3, # AI diminishes if used less than this threshold
        ai_evolution_increment=0.5, # Amount AI's contribution changes upon evolution
        attitude_positive_threshold=0.5, # Threshold to become more positive
        attitude_negative_threshold=-0.5, # Threshold to become more negative
        dynamic_network=True,      # Enable dynamic network changes
        network_change_frequency=10, # Steps between network changes
        num_edges_change=5          # Number of edges to add/remove during each network change
    )

    # Optionally, visualize the networks before running the model
    model.visualize_networks()

    # Run the model for a specified number of steps
    model.run_model(n_steps=100)
    model.create_network_animations()

if __name__ == "__main__":
    main()
# Out:
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 2.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 3.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 3.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 4.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 4.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 5.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 5.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 6.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 6.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 7.0
# Modifying social network at step 10...
# Removed 5 random edges.
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# Step 10 completed.
# AI evolved! New knowledge contribution: 7.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 8.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 8.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 9.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 9.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 10.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 10.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 11.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 11.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 12.0
# Modifying social network at step 20...
# Added 5 random edges.
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# Step 20 completed.
# AI evolved! New knowledge contribution: 12.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 13.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 13.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 14.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 14.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 15.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 15.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 16.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 16.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 17.0
# Modifying social network at step 30...
# Added 5 random edges.
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# Step 30 completed.
# AI evolved! New knowledge contribution: 17.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 18.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 18.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 19.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 19.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 20.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 20.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 21.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 21.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 22.0
# Modifying social network at step 40...
# Added 5 random edges.
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# Step 40 completed.
# AI evolved! New knowledge contribution: 22.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 23.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 23.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 24.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 24.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 25.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 25.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 26.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 26.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 27.0
# Modifying social network at step 50...
# Removed 5 random edges.
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# Step 50 completed.
# AI evolved! New knowledge contribution: 27.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 28.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 28.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 29.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 29.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 30.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 30.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 31.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 31.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 32.0
# Modifying social network at step 60...
# Added 5 random edges.
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# Step 60 completed.
# AI evolved! New knowledge contribution: 32.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 33.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 33.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 34.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 34.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 35.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 35.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 36.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 36.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 37.0
# Modifying social network at step 70...
# Added 5 random edges.
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# Step 70 completed.
# AI evolved! New knowledge contribution: 37.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 38.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 38.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 39.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 39.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 40.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 40.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 41.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 41.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 42.0
# Modifying social network at step 80...
# Removed 5 random edges.
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# Step 80 completed.
# AI evolved! New knowledge contribution: 42.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 43.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 43.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 44.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 44.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 45.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 45.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 46.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 46.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 47.0
# Modifying social network at step 90...
# Removed 5 random edges.
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# Step 90 completed.
# AI evolved! New knowledge contribution: 47.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 48.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 48.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 49.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 49.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 50.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 50.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 51.0
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 51.5
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# AI evolved! New knowledge contribution: 52.0
# Modifying social network at step 100...
# Added 5 random edges.
# Network visualizations saved in: /Users/zach/Documents/GitHub/abm_OOP_ai_organizations/network_visualizations
# Step 100 completed.
# Simulation completed. Results saved to 'data/results.csv'.
